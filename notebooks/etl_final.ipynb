# %% [markdown]
# # Обработка датасета

# %% [markdown]
# ## Библиотеки и скрипты

# %%
import numpy as np
import pandas as pd
import re
from transliterate import translit, get_available_language_codes

# Библиотека для предобработки датасетов
import os, sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
from data_preprocessing import DataPreprocessor
dp = DataPreprocessor()

# Отключаем предупреждения
import warnings
warnings.simplefilter('ignore')

# %%
# Получение ClientID
def get_id(x):
    id = re.search('YA:.*', x).group(0)
    return re.sub('YA:', '', id).strip()

# %% [markdown]
# ## Обзор данных

# %%
# Загружаем датасеты
df1 = pd.read_csv('../data/td_metrika.csv', ';')
df2 = pd.read_csv('../data/td_site.csv', ';')
df3 = pd.read_csv('../data/td_crm.csv', ';')

# %%
df1.head()
# Out:
#            ym_clientid ym_pervyj_istochnik_trafika      ym_source  \
# 0    15785624736522097                  Ad-Traffic      undefined
# 1   158240803283368197             Browser-Traffic      undefined
# 2  1594782414605357519                  Ad-Traffic      undefined
# 3  1595636421722944149                  Ad-Traffic      undefined
# 4  1600595766306691164                  Ad-Traffic  yad > 300x300
#
#   ym_pervyj_perehod_s_sajtov ym_pervaja_poiskovaja_sistema ym_utm_source  \
# 0                  undefined                     undefined     undefined
# 1                  undefined                     undefined     undefined
# 2                  undefined                     undefined     undefined
# 3                  undefined                     undefined     undefined
# 4                  undefined                     undefined           yad
#
#   ym_utm_content    ym_gorod ym_data_vizita  ym_cost  ... ym_vremja_na_sajte  \
# 0      undefined   undefined     2020-01-11     15.0  ...           00:21:41
# 1      undefined   undefined     2020-02-23      0.0  ...           00:00:00
# 2      undefined   undefined     2020-07-21     15.0  ...           00:00:00
# 3      undefined  Нур-Султан     2020-07-25     15.0  ...           00:00:00
# 4        300x300   undefined     2020-09-20     15.0  ...           00:00:10
#
#    ym_novye_posetiteli  ym_dnej_mezhdu_vizitami  ym_vernuvshiesja_1_den  \
# 0                    0                 0.000000                0.933333
# 1                   15                 0.000000                0.000000
# 2                    0                 0.357143                0.928571
# 3                    1                 0.000000                0.928571
# 4                    1                 0.000000                0.909091
#
#   ym_vernuvshiesja_2_7_dnej  ym_dostizhenija_ljuboj_tseli  \
# 0                  0.066667                            57
# 1                  0.000000                             4
# 2                  0.071429                             0
# 3                  0.000000                             0
# 4                  0.000000                             0
#
#    ym_dostignutaja_tsel  ym_put_polnyj_stranitsy_vhoda  \
# 0             undefined                      undefined
# 1             undefined                      undefined
# 2             undefined                      undefined
# 3             undefined                   /#secondPage
# 4             undefined                      undefined
#
#    ym_put_polnyj_stranitsy_vyhoda  ym_mobilnost
# 0                       undefined     undefined
# 1                       undefined     undefined
# 2                       undefined     undefined
# 3                    /#secondPage             1
# 4                       undefined     undefined
#
# [5 rows x 24 columns]

# %%
df1.shape
# Out:
# (58882, 24)

# %%
df2.head()
# Out:
#               st_id_ym                     st_id_ga           st_created  \
# 0  1609586985682049430   GA1.2.934928888.1609586985  2021-01-02 14:30:42
# 1  1609610415617206319   GA1.2.233829537.1609610416  2021-01-02 21:01:43
# 2  1609623797665217591    GA1.2.52594619.1609623797  2021-01-03 00:46:09
# 3   160964815239544789  GA1.2.1046709437.1609648153  2021-01-03 07:30:46
# 4  1609662851665134598   GA1.2.300748215.1609662851  2021-01-03 11:35:45
#
#   st_location                                   st_branch  \
# 0       Kazan                        Мобильные сотрудники
# 1     Barnaul                       Телекоммуникации и ИТ
# 2       Minsk  Управление самозанятыми, ИП и подрядчиками
# 3     Barnaul          Выездное обслуживание оборудования
# 4     Shakhty          Выездное обслуживание оборудования
#
#                      st_direction  st_amount  st_price
# 0            Строительные бригады          3    5000.0
# 1              Выездной ИТ-сервис          5    5000.0
# 2    Управление ИП и самозанятыми          3    5000.0
# 3  Кондиционирование и вентиляция          3    5000.0
# 4    Технологическое оборудование          1    5000.0

# %%
df2.shape
# Out:
# (943, 8)

# %%
df3.head()
# Out:
#          crm_client_id  crm_id crm_data_sozdanija          crm_status  \
# 0  1615817020919653525   10071    01.04.2021 1:01  Некачественный лид
# 1  1615817020919653525   10069    01.04.2021 1:00           Обработан
# 2  1617218182652379262   10067   31.03.2021 22:18           Обработан
# 3            undefined   10065   31.03.2021 14:52           Обработан
# 4  1617186237647777106   10063   31.03.2021 13:59           Обработан
#
#          crm_nazvanie_lida crm_obraschenie                 crm_imja  \
# 0              Алтимо UA R       undefined                  Дмитрий
# 1              Алтимо UA R       undefined                  Дмитрий
# 2               One&Double       undefined         Милехина Надежда
# 3                 Тимур UA       undefined                    Тимур
# 4  Лебедев Николай Юрьевич       undefined  Лебедев Николай Юрьевич
#
#   crm_otchestvo crm_familija crm_dolzhnost  ... crm_valjuta crm_povtornyj_lid  \
# 0     undefined    undefined      Директор  ...       Рубль                 N
# 1     undefined    undefined      Директор  ...       Рубль                 N
# 2     undefined    undefined  Руководитель  ...       Рубль                 N
# 3     undefined    undefined     undefined  ...       Рубль                 N
# 4     undefined    undefined     undefined  ...       Рубль                 N
#
#   crm_utm_source crm_utm_medium crm_utm_campaign crm_utm_content crm_utm_term  \
# 0      undefined      undefined        undefined       undefined    undefined
# 1      undefined      undefined        undefined       undefined    undefined
# 2      undefined      undefined        undefined       undefined    undefined
# 3      undefined      undefined        undefined       undefined    undefined
# 4      undefined      undefined        undefined       undefined    undefined
#
#   crm_klassifikator_otrasli                                        crm_otrasl  \
# 0                 undefined                                         undefined
# 1                 undefined  Выездное обслуживание оборудования - Спецтехника
# 2                 undefined                                         undefined
# 3                 undefined                                         undefined
# 4                 undefined                                         undefined
#
#    crm_otrasl_spisok
# 0          undefined
# 1          undefined
# 2          undefined
# 3          undefined
# 4          undefined
#
# [5 rows x 31 columns]

# %%
df3.shape
# Out:
# (1407, 31)

# %% [markdown]
# ## Обработка данных

# %%
# Переименование и сортировка
df2.rename(columns={'st_id_ym': 'ym_clientid'}, inplace=True)
df2 = df2[df2['ym_clientid'] != 'undefined']
df2
# Out:
#               ym_clientid                     st_id_ga           st_created  \
# 0     1609586985682049430   GA1.2.934928888.1609586985  2021-01-02 14:30:42
# 1     1609610415617206319   GA1.2.233829537.1609610416  2021-01-02 21:01:43
# 2     1609623797665217591    GA1.2.52594619.1609623797  2021-01-03 00:46:09
# 3      160964815239544789  GA1.2.1046709437.1609648153  2021-01-03 07:30:46
# 4     1609662851665134598   GA1.2.300748215.1609662851  2021-01-03 11:35:45
# ..                    ...                          ...                  ...
# 938   1617219379343036650    GA1.2.55417926.1617219379  2021-03-31 22:37:09
# 939  16172198711052056724  GA1.2.1103031021.1617219872  2021-03-31 22:46:41
# 940   1617237997505730112  GA1.2.1716267377.1617237997  2021-04-01 05:07:58
# 941   1617250473558704891   GA1.2.158390038.1617250473  2021-04-01 07:17:17
# 942   1617254917161658237   GA1.2.223412910.1617254918  2021-04-01 08:33:02
#
#      st_location                                   st_branch  \
# 0          Kazan                        Мобильные сотрудники
# 1        Barnaul                       Телекоммуникации и ИТ
# 2          Minsk  Управление самозанятыми, ИП и подрядчиками
# 3        Barnaul          Выездное обслуживание оборудования
# 4        Shakhty          Выездное обслуживание оборудования
# ..           ...                                         ...
# 938       Moscow          Выездное обслуживание оборудования
# 939       Almaty                        Мобильные сотрудники
# 940  Chelyabinsk          Выездное обслуживание оборудования
# 941       Almaty                        Мобильные сотрудники
# 942       Moscow          Выездное обслуживание оборудования
#
#                        st_direction  st_amount  st_price
# 0              Строительные бригады          3    5000.0
# 1                Выездной ИТ-сервис          5    5000.0
# 2      Управление ИП и самозанятыми          3    5000.0
# 3    Кондиционирование и вентиляция          3    5000.0
# 4      Технологическое оборудование          1    5000.0
# ..                              ...        ...       ...
# 938    Оргтехника и ИТ-оборудование         10    9500.0
# 939              Выездной сервис IT         20   17500.0
# 940    Технологическое оборудование          5    5000.0
# 941                        Водители          5    3700.0
# 942    Технологическое оборудование         15   13500.0
#
# [943 rows x 8 columns]

# %%
# Слияние датасетов
df4 = pd.merge(df1, df2, how='left')
df4
# Out:
#                 ym_clientid ym_pervyj_istochnik_trafika  \
# 0         15785624736522097                  Ad-Traffic
# 1        158240803283368197             Browser-Traffic
# 2       1594782414605357519                  Ad-Traffic
# 3       1595636421722944149                  Ad-Traffic
# 4       1600595766306691164                  Ad-Traffic
# ...                     ...                         ...
# 58877  16172709101051592622                  Ad-Traffic
# 58878  16172727801073292667                  Ad-Traffic
# 58879  16172753631015177105                      Search
# 58880  16172780011038921256                  Ad-Traffic
# 58881  16442514621041454836             Browser-Traffic
#
#                            ym_source ym_pervyj_perehod_s_sajtov  \
# 0                          undefined                  undefined
# 1                          undefined                  undefined
# 2                          undefined                  undefined
# 3                          undefined                  undefined
# 4                      yad > 300x300                  undefined
# ...                              ...                        ...
# 58877  yandex > kontrol_mobile_stuff                  undefined
# 58878     yandex > dispetcherisatzia                  undefined
# 58879                         yandex                  undefined
# 58880  yandex > kontrol_mobile_stuff                  undefined
# 58881                      undefined                  undefined
#
#       ym_pervaja_poiskovaja_sistema ym_utm_source        ym_utm_content  \
# 0                         undefined     undefined             undefined
# 1                         undefined     undefined             undefined
# 2                         undefined     undefined             undefined
# 3                         undefined     undefined             undefined
# 4                         undefined           yad               300x300
# ...                             ...           ...                   ...
# 58877                     undefined        yandex  kontrol_mobile_stuff
# 58878                     undefined        yandex     dispetcherisatzia
# 58879                        Яндекс     undefined             undefined
# 58880                     undefined        yandex  kontrol_mobile_stuff
# 58881                     undefined     undefined             undefined
#
#          ym_gorod ym_data_vizita  ym_cost  ...  \
# 0       undefined     2020-01-11     15.0  ...
# 1       undefined     2020-02-23      0.0  ...
# 2       undefined     2020-07-21     15.0  ...
# 3      Нур-Султан     2020-07-25     15.0  ...
# 4       undefined     2020-09-20     15.0  ...
# ...           ...            ...      ...  ...
# 58877   undefined     2021-04-01     15.0  ...
# 58878   Краснодар     2021-04-01     15.0  ...
# 58879    Шадринск     2021-04-01     48.5  ...
# 58880   Челябинск     2021-04-01     15.0  ...
# 58881   Гамильтон     2021-03-07      0.0  ...
#
#                            ym_put_polnyj_stranitsy_vhoda  \
# 0                                              undefined
# 1                                              undefined
# 2                                              undefined
# 3                                           /#secondPage
# 4                                              undefined
# ...                                                  ...
# 58877                                                  /
# 58878                                                  /
# 58879  /uchet-oborudovaniya-i-upravlenie-remontami/ch...
# 58880                                                  /
# 58881                                                  /
#
#        ym_put_polnyj_stranitsy_vyhoda  ym_mobilnost  st_id_ga st_created  \
# 0                           undefined     undefined       NaN        NaN
# 1                           undefined     undefined       NaN        NaN
# 2                           undefined     undefined       NaN        NaN
# 3                        /#secondPage             1       NaN        NaN
# 4                           undefined     undefined       NaN        NaN
# ...                               ...           ...       ...        ...
# 58877                               /             1       NaN        NaN
# 58878                               /             0       NaN        NaN
# 58879                          /#cost             0       NaN        NaN
# 58880                               /             1       NaN        NaN
# 58881                               /             0       NaN        NaN
#
#        st_location  st_branch  st_direction  st_amount  st_price
# 0              NaN        NaN           NaN        NaN       NaN
# 1              NaN        NaN           NaN        NaN       NaN
# 2              NaN        NaN           NaN        NaN       NaN
# 3              NaN        NaN           NaN        NaN       NaN
# 4              NaN        NaN           NaN        NaN       NaN
# ...            ...        ...           ...        ...       ...
# 58877          NaN        NaN           NaN        NaN       NaN
# 58878          NaN        NaN           NaN        NaN       NaN
# 58879          NaN        NaN           NaN        NaN       NaN
# 58880          NaN        NaN           NaN        NaN       NaN
# 58881          NaN        NaN           NaN        NaN       NaN
#
# [58882 rows x 31 columns]

# %%
df4.shape
# Out:
# (58882, 31)

# %%
df_test = df4.loc[(~df4['ym_data_vizita'].isnull()) & (~df4['st_created'].isnull())]
df_test
# Out:
#                 ym_clientid ym_pervyj_istochnik_trafika  \
# 6       1544792334967355948             Browser-Traffic
# 30      1594305260967432217                Site-Traffic
# 52      1599476927749455055                       Sites
# 65      1611327138987509272                  Ad-Traffic
# 73       160974333838123157             Browser-Traffic
# ...                     ...                         ...
# 58843  16169975541064824206                      Search
# 58852  16170938571008150421                       Sites
# 58859  16171720051030854837                      Search
# 58866  16171943301044869869             Browser-Traffic
# 58870  16172198711052056724                      Search
#
#                             ym_source ym_pervyj_perehod_s_sajtov  \
# 6                           undefined                  undefined
# 30                          undefined                  undefined
# 52                        hubex.cloud                hubex.cloud
# 65     yandex > sistema_obslyzhivanie                  undefined
# 73                          undefined                  undefined
# ...                               ...                        ...
# 58843                          yandex                  undefined
# 58852                    helpdeski.ru               helpdeski.ru
# 58859                          google                  undefined
# 58866                       undefined                  undefined
# 58870                          google                  undefined
#
#       ym_pervaja_poiskovaja_sistema ym_utm_source         ym_utm_content  \
# 6                         undefined     undefined              undefined
# 30                        undefined     undefined              undefined
# 52                        undefined     undefined              undefined
# 65                        undefined        yandex  sistema_obslyzhivanie
# 73                        undefined     undefined              undefined
# ...                             ...           ...                    ...
# 58843                        Яндекс     undefined              undefined
# 58852                     undefined     undefined              undefined
# 58859                        Google     undefined              undefined
# 58866                     undefined     undefined              undefined
# 58870                        Google     undefined              undefined
#
#            ym_gorod ym_data_vizita  ym_cost  ...  \
# 6         undefined     2020-06-26      0.0  ...
# 30        undefined     2021-01-12      0.0  ...
# 52        undefined     2020-11-10      0.0  ...
# 65        undefined     2021-01-27     15.0  ...
# 73        undefined     2021-01-04      0.0  ...
# ...             ...            ...      ...  ...
# 58843  Благовещенск     2021-03-29     48.5  ...
# 58852     undefined     2021-03-30      0.0  ...
# 58859         Сатка     2021-03-31     48.5  ...
# 58866          Баку     2021-03-31      0.0  ...
# 58870        Алматы     2021-03-31     48.5  ...
#
#                            ym_put_polnyj_stranitsy_vhoda  \
# 6                                              undefined
# 30                                             undefined
# 52                                             undefined
# 65                                             undefined
# 73                                             undefined
# ...                                                  ...
# 58843                                         /platform/
# 58852                                                  /
# 58859                                                  /
# 58866                                                  /
# 58870  /news/hubex-dobavili-geolokacziyu-mobilnyh-sot...
#
#        ym_put_polnyj_stranitsy_vyhoda  ym_mobilnost  \
# 6                           undefined     undefined
# 30                          undefined     undefined
# 52                          undefined     undefined
# 65                          undefined     undefined
# 73                          undefined     undefined
# ...                               ...           ...
# 58843                          /#cost             0
# 58852                               /             0
# 58859                               /             1
# 58866                               /             0
# 58870                          /#cost             0
#
#                           st_id_ga           st_created      st_location  \
# 6      GA1.2.1713812683.1549898347  2021-02-04 18:45:53          Armavir
# 30     GA1.2.1818583493.1602833721  2021-01-19 10:57:04    St Petersburg
# 52     GA1.2.1341876302.1599476926  2021-02-18 18:24:24    St Petersburg
# 65     GA1.2.2122525885.1611327141  2021-01-22 17:52:49           Tambov
# 73     GA1.2.1511795731.1609743339  2021-01-04 10:01:11           Moscow
# ...                            ...                  ...              ...
# 58843  GA1.2.1256306549.1616997554  2021-03-29 08:59:58  Blagoveshchensk
# 58852                    undefined  2021-03-30 11:45:11      Cherepovets
# 58859   GA1.2.903918022.1617172006  2021-03-31 09:27:12       Kropachëvo
# 58866  GA1.2.2057556913.1617194330  2021-03-31 15:43:37             Baku
# 58870  GA1.2.1103031021.1617219872  2021-03-31 22:46:41           Almaty
#
#                                         st_branch  \
# 6              Выездное обслуживание оборудования
# 30                           Мобильные сотрудники
# 52             Выездное обслуживание оборудования
# 65             Выездное обслуживание оборудования
# 73                          Телекоммуникации и ИТ
# ...                                           ...
# 58843                        Мобильные сотрудники
# 58852  Управление самозанятыми, ИП и подрядчиками
# 58859                       Телекоммуникации и ИТ
# 58866          Выездное обслуживание оборудования
# 58870                        Мобильные сотрудники
#
#                                      st_direction  st_amount  st_price
# 6                   Постаматы, вендинг, банкоматы      150.0  118700.0
# 30                                        Клининг        5.0    7000.0
# 52                  Постаматы, вендинг, банкоматы      244.0    5000.0
# 65                   Технологическое оборудование       10.0    9500.0
# 73                  Контроль выездных монтажников        3.0    5000.0
# ...                                           ...        ...       ...
# 58843                    GPS-мониторинг персонала       90.0   32200.0
# 58852  Управление самозанятыми, ИП и подрядчиками       10.0       0.0
# 58859                       Телекоммуникации и ИТ        1.0       0.0
# 58866                Технологическое оборудование      120.0   95600.0
# 58870                          Выездной сервис IT       20.0   17500.0
#
# [1033 rows x 31 columns]

# %%
# Переименование столбца и добавление префиксов
df3.rename(columns={'crm_client_id': 'ym_clientid'}, inplace=True)
df3.loc[df3['ym_clientid'] != 'undefined', 'ym_clientid'] = 'YA:' + df3['ym_clientid'].astype(str)
df3
# Out:
#                  ym_clientid  crm_id crm_data_sozdanija          crm_status  \
# 0     YA:1615817020919653525   10071    01.04.2021 1:01  Некачественный лид
# 1     YA:1615817020919653525   10069    01.04.2021 1:00           Обработан
# 2     YA:1617218182652379262   10067   31.03.2021 22:18           Обработан
# 3                  undefined   10065   31.03.2021 14:52           Обработан
# 4     YA:1617186237647777106   10063   31.03.2021 13:59           Обработан
# ...                      ...     ...                ...                 ...
# 1402               undefined     545   25.04.2019 11:31    Качественный лид
# 1403               undefined     531    20.04.2019 9:43    Качественный лид
# 1404               undefined     527   18.04.2019 21:44  Некачественный лид
# 1405               undefined     523   17.04.2019 19:00  Некачественный лид
# 1406               undefined     519    17.04.2019 9:12  Некачественный лид
#
#             crm_nazvanie_lida crm_obraschenie                    crm_imja  \
# 0                 Алтимо UA R       undefined                     Дмитрий
# 1                 Алтимо UA R       undefined                     Дмитрий
# 2                  One&Double       undefined            Милехина Надежда
# 3                    Тимур UA       undefined                       Тимур
# 4     Лебедев Николай Юрьевич       undefined     Лебедев Николай Юрьевич
# ...                       ...             ...                         ...
# 1402                  FlexNep       undefined                     FlexNep
# 1403           ЛокоТех Сервис       undefined  Одинаев Амаль Зайнидинович
# 1404              ИП Гончаров       undefined         Vladislav Goncharov
# 1405            ААГ (+2 часа)       undefined             Романов Алексей
# 1406                  Coffect       undefined                     Евгений
#
#      crm_otchestvo crm_familija crm_dolzhnost  ... crm_valjuta  \
# 0        undefined    undefined      Директор  ...       Рубль
# 1        undefined    undefined      Директор  ...       Рубль
# 2        undefined    undefined  Руководитель  ...       Рубль
# 3        undefined    undefined     undefined  ...       Рубль
# 4        undefined    undefined     undefined  ...       Рубль
# ...            ...          ...           ...  ...         ...
# 1402     undefined    undefined     undefined  ...       Рубль
# 1403     undefined    undefined     undefined  ...       Рубль
# 1404     undefined    undefined     undefined  ...       Рубль
# 1405     undefined    undefined     undefined  ...       Рубль
# 1406     undefined    undefined     undefined  ...       Рубль
#
#      crm_povtornyj_lid crm_utm_source crm_utm_medium crm_utm_campaign  \
# 0                    N      undefined      undefined        undefined
# 1                    N      undefined      undefined        undefined
# 2                    N      undefined      undefined        undefined
# 3                    N      undefined      undefined        undefined
# 4                    N      undefined      undefined        undefined
# ...                ...            ...            ...              ...
# 1402                 N      undefined      undefined        undefined
# 1403                 N      undefined      undefined        undefined
# 1404                 N      undefined      undefined        undefined
# 1405                 N      undefined      undefined        undefined
# 1406                 N      undefined      undefined        undefined
#
#      crm_utm_content crm_utm_term crm_klassifikator_otrasli  \
# 0          undefined    undefined                 undefined
# 1          undefined    undefined                 undefined
# 2          undefined    undefined                 undefined
# 3          undefined    undefined                 undefined
# 4          undefined    undefined                 undefined
# ...              ...          ...                       ...
# 1402       undefined    undefined                 undefined
# 1403       undefined    undefined                 undefined
# 1404       undefined    undefined                 undefined
# 1405       undefined    undefined                 undefined
# 1406       undefined    undefined                 undefined
#
#                                             crm_otrasl  \
# 0                                            undefined
# 1     Выездное обслуживание оборудования - Спецтехника
# 2                                            undefined
# 3                                            undefined
# 4                                            undefined
# ...                                                ...
# 1402                        Производство печатных плат
# 1403                       Сервисное локомотивное депо
# 1404                                         undefined
# 1405                                         undefined
# 1406                                         undefined
#
#               crm_otrasl_spisok
# 0                     undefined
# 1                     undefined
# 2                     undefined
# 3                     undefined
# 4                     undefined
# ...                         ...
# 1402                  undefined
# 1403  Сервис (депо, жд техника)
# 1404                  undefined
# 1405                  undefined
# 1406                  undefined
#
# [1407 rows x 31 columns]

# %%
df4.loc[df4['ym_clientid'] != 'undefined', 'ym_clientid'] = 'YA:' + df4['ym_clientid'].astype(str)
df4
# Out:
#                    ym_clientid ym_pervyj_istochnik_trafika  \
# 0         YA:15785624736522097                  Ad-Traffic
# 1        YA:158240803283368197             Browser-Traffic
# 2       YA:1594782414605357519                  Ad-Traffic
# 3       YA:1595636421722944149                  Ad-Traffic
# 4       YA:1600595766306691164                  Ad-Traffic
# ...                        ...                         ...
# 58877  YA:16172709101051592622                  Ad-Traffic
# 58878  YA:16172727801073292667                  Ad-Traffic
# 58879  YA:16172753631015177105                      Search
# 58880  YA:16172780011038921256                  Ad-Traffic
# 58881  YA:16442514621041454836             Browser-Traffic
#
#                            ym_source ym_pervyj_perehod_s_sajtov  \
# 0                          undefined                  undefined
# 1                          undefined                  undefined
# 2                          undefined                  undefined
# 3                          undefined                  undefined
# 4                      yad > 300x300                  undefined
# ...                              ...                        ...
# 58877  yandex > kontrol_mobile_stuff                  undefined
# 58878     yandex > dispetcherisatzia                  undefined
# 58879                         yandex                  undefined
# 58880  yandex > kontrol_mobile_stuff                  undefined
# 58881                      undefined                  undefined
#
#       ym_pervaja_poiskovaja_sistema ym_utm_source        ym_utm_content  \
# 0                         undefined     undefined             undefined
# 1                         undefined     undefined             undefined
# 2                         undefined     undefined             undefined
# 3                         undefined     undefined             undefined
# 4                         undefined           yad               300x300
# ...                             ...           ...                   ...
# 58877                     undefined        yandex  kontrol_mobile_stuff
# 58878                     undefined        yandex     dispetcherisatzia
# 58879                        Яндекс     undefined             undefined
# 58880                     undefined        yandex  kontrol_mobile_stuff
# 58881                     undefined     undefined             undefined
#
#          ym_gorod ym_data_vizita  ym_cost  ...  \
# 0       undefined     2020-01-11     15.0  ...
# 1       undefined     2020-02-23      0.0  ...
# 2       undefined     2020-07-21     15.0  ...
# 3      Нур-Султан     2020-07-25     15.0  ...
# 4       undefined     2020-09-20     15.0  ...
# ...           ...            ...      ...  ...
# 58877   undefined     2021-04-01     15.0  ...
# 58878   Краснодар     2021-04-01     15.0  ...
# 58879    Шадринск     2021-04-01     48.5  ...
# 58880   Челябинск     2021-04-01     15.0  ...
# 58881   Гамильтон     2021-03-07      0.0  ...
#
#                            ym_put_polnyj_stranitsy_vhoda  \
# 0                                              undefined
# 1                                              undefined
# 2                                              undefined
# 3                                           /#secondPage
# 4                                              undefined
# ...                                                  ...
# 58877                                                  /
# 58878                                                  /
# 58879  /uchet-oborudovaniya-i-upravlenie-remontami/ch...
# 58880                                                  /
# 58881                                                  /
#
#        ym_put_polnyj_stranitsy_vyhoda  ym_mobilnost  st_id_ga st_created  \
# 0                           undefined     undefined       NaN        NaN
# 1                           undefined     undefined       NaN        NaN
# 2                           undefined     undefined       NaN        NaN
# 3                        /#secondPage             1       NaN        NaN
# 4                           undefined     undefined       NaN        NaN
# ...                               ...           ...       ...        ...
# 58877                               /             1       NaN        NaN
# 58878                               /             0       NaN        NaN
# 58879                          /#cost             0       NaN        NaN
# 58880                               /             1       NaN        NaN
# 58881                               /             0       NaN        NaN
#
#        st_location  st_branch  st_direction  st_amount  st_price
# 0              NaN        NaN           NaN        NaN       NaN
# 1              NaN        NaN           NaN        NaN       NaN
# 2              NaN        NaN           NaN        NaN       NaN
# 3              NaN        NaN           NaN        NaN       NaN
# 4              NaN        NaN           NaN        NaN       NaN
# ...            ...        ...           ...        ...       ...
# 58877          NaN        NaN           NaN        NaN       NaN
# 58878          NaN        NaN           NaN        NaN       NaN
# 58879          NaN        NaN           NaN        NaN       NaN
# 58880          NaN        NaN           NaN        NaN       NaN
# 58881          NaN        NaN           NaN        NaN       NaN
#
# [58882 rows x 31 columns]

# %%
# Слияние датасетов
df = pd.merge(df4, df3, how='outer')
df.head(10)
# Out:
#               ym_clientid ym_pervyj_istochnik_trafika      ym_source  \
# 0    YA:15785624736522097                  Ad-Traffic      undefined
# 1   YA:158240803283368197             Browser-Traffic      undefined
# 2  YA:1594782414605357519                  Ad-Traffic      undefined
# 3  YA:1595636421722944149                  Ad-Traffic      undefined
# 4  YA:1600595766306691164                  Ad-Traffic  yad > 300x300
# 5  YA:1600595766306691164                  Ad-Traffic  yad > 300x300
# 6  YA:1603390261565159009                  Ad-Traffic  yad > 240x400
# 7  YA:1603390261565159009                  Ad-Traffic  yad > 240x400
# 8  YA:1544792334967355948             Browser-Traffic      undefined
# 9  YA:1580315607562323972                  Ad-Traffic      undefined
#
#   ym_pervyj_perehod_s_sajtov ym_pervaja_poiskovaja_sistema ym_utm_source  \
# 0                  undefined                     undefined     undefined
# 1                  undefined                     undefined     undefined
# 2                  undefined                     undefined     undefined
# 3                  undefined                     undefined     undefined
# 4                  undefined                     undefined           yad
# 5                  undefined                     undefined           yad
# 6                  undefined                     undefined           yad
# 7                  undefined                     undefined           yad
# 8                  undefined                     undefined     undefined
# 9                  undefined                     undefined     undefined
#
#   ym_utm_content    ym_gorod ym_data_vizita  ym_cost  ... crm_valjuta  \
# 0      undefined   undefined     2020-01-11     15.0  ...         NaN
# 1      undefined   undefined     2020-02-23      0.0  ...         NaN
# 2      undefined   undefined     2020-07-21     15.0  ...         NaN
# 3      undefined  Нур-Султан     2020-07-25     15.0  ...         NaN
# 4        300x300   undefined     2020-09-20     15.0  ...         NaN
# 5        300x300   undefined     2020-09-28     15.0  ...         NaN
# 6        240x400   undefined     2020-10-26     15.0  ...         NaN
# 7        240x400   undefined     2020-10-22     15.0  ...         NaN
# 8      undefined   undefined     2020-06-26      0.0  ...         NaN
# 9      undefined   undefined     2020-01-29     15.0  ...         NaN
#
#    crm_povtornyj_lid  crm_utm_source  crm_utm_medium crm_utm_campaign  \
# 0                NaN             NaN             NaN              NaN
# 1                NaN             NaN             NaN              NaN
# 2                NaN             NaN             NaN              NaN
# 3                NaN             NaN             NaN              NaN
# 4                NaN             NaN             NaN              NaN
# 5                NaN             NaN             NaN              NaN
# 6                NaN             NaN             NaN              NaN
# 7                NaN             NaN             NaN              NaN
# 8                NaN             NaN             NaN              NaN
# 9                NaN             NaN             NaN              NaN
#
#    crm_utm_content  crm_utm_term  crm_klassifikator_otrasli  crm_otrasl  \
# 0              NaN           NaN                        NaN         NaN
# 1              NaN           NaN                        NaN         NaN
# 2              NaN           NaN                        NaN         NaN
# 3              NaN           NaN                        NaN         NaN
# 4              NaN           NaN                        NaN         NaN
# 5              NaN           NaN                        NaN         NaN
# 6              NaN           NaN                        NaN         NaN
# 7              NaN           NaN                        NaN         NaN
# 8              NaN           NaN                        NaN         NaN
# 9              NaN           NaN                        NaN         NaN
#
#    crm_otrasl_spisok
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
#
# [10 rows x 61 columns]

# %%
df.shape
# Out:
# (60108, 61)

# %%
df_test = df.loc[(~df['ym_data_vizita'].isnull()) & (~df['crm_data_sozdanija'].isnull())]
df_test
# Out:
#                    ym_clientid ym_pervyj_istochnik_trafika        ym_source  \
# 177     YA:1608109343263058676                       Sites     helpdeski.ru
# 178     YA:1608109343263058676                       Sites     helpdeski.ru
# 182     YA:1611506869820188371                       Sites     helpdeski.ru
# 183     YA:1611506869820188371                       Sites     helpdeski.ru
# 191     YA:1614355048925217154                      Search           google
# ...                        ...                         ...              ...
# 58571  YA:16141083841028982888             Browser-Traffic        undefined
# 58653  YA:16150038881044475721                      Search           yandex
# 58711  YA:16154795451028730737                       Sites  livebusiness.ru
# 58715  YA:16155322781071508900                      Search           google
# 58865  YA:16170938571008150421                       Sites     helpdeski.ru
#
#       ym_pervyj_perehod_s_sajtov ym_pervaja_poiskovaja_sistema ym_utm_source  \
# 177                 helpdeski.ru                     undefined     undefined
# 178                 helpdeski.ru                     undefined     undefined
# 182                 helpdeski.ru                     undefined     undefined
# 183                 helpdeski.ru                     undefined     undefined
# 191                    undefined                        Google     undefined
# ...                          ...                           ...           ...
# 58571                  undefined                     undefined     undefined
# 58653                  undefined                        Яндекс     undefined
# 58711            livebusiness.ru                     undefined     undefined
# 58715                  undefined                        Google     undefined
# 58865               helpdeski.ru                     undefined     undefined
#
#       ym_utm_content    ym_gorod ym_data_vizita  ym_cost  ... crm_valjuta  \
# 177        undefined   undefined     2020-12-16      0.0  ...       Рубль
# 178        undefined   undefined     2020-12-17      0.0  ...       Рубль
# 182        undefined   undefined     2021-02-08      0.0  ...       Рубль
# 183        undefined   undefined     2021-01-24      0.0  ...       Рубль
# 191        undefined   undefined     2021-03-01     48.5  ...       Рубль
# ...              ...         ...            ...      ...  ...         ...
# 58571      undefined      Липецк     2021-02-23      0.0  ...       Рубль
# 58653      undefined  Красноярск     2021-03-06     48.5  ...       Рубль
# 58711      undefined      Тюмень     2021-03-11      0.0  ...       Рубль
# 58715      undefined      Москва     2021-03-12     48.5  ...       Рубль
# 58865      undefined   undefined     2021-03-30      0.0  ...       Рубль
#
#        crm_povtornyj_lid  crm_utm_source  crm_utm_medium crm_utm_campaign  \
# 177                    N       undefined       undefined        undefined
# 178                    N       undefined       undefined        undefined
# 182                    N       undefined       undefined        undefined
# 183                    N       undefined       undefined        undefined
# 191                    N       undefined       undefined        undefined
# ...                  ...             ...             ...              ...
# 58571                  N       undefined       undefined        undefined
# 58653                  N       undefined       undefined        undefined
# 58711                  N       undefined       undefined        undefined
# 58715                  N       undefined       undefined        undefined
# 58865                  N       undefined       undefined        undefined
#
#        crm_utm_content  crm_utm_term  \
# 177          undefined     undefined
# 178          undefined     undefined
# 182          undefined     undefined
# 183          undefined     undefined
# 191          undefined     undefined
# ...                ...           ...
# 58571        undefined     undefined
# 58653        undefined     undefined
# 58711        undefined     undefined
# 58715        undefined     undefined
# 58865        undefined     undefined
#
#                                crm_klassifikator_otrasli  \
# 177        1. Сервисное выездное обслуживание\t/\tДругое
# 178        1. Сервисное выездное обслуживание\t/\tДругое
# 182                                            undefined
# 183                                            undefined
# 191                  6. Телекоммуникации и ИТ\t/\tДругое
# ...                                                  ...
# 58571                                          undefined
# 58653  5. Промышленность, нефтегаз, ТЭК\t/\tОбслужива...
# 58711  1. Сервисное выездное обслуживание\t/\tСпецтех...
# 58715  1. Сервисное выездное обслуживание\t/\tСпецтех...
# 58865  6. Телекоммуникации и ИТ\t/\tККТ, автоматизаци...
#
#                             crm_otrasl  crm_otrasl_spisok
# 177                  Сервис банкоматов          undefined
# 178                  Сервис банкоматов          undefined
# 182                          undefined          undefined
# 183                          undefined          undefined
# 191                          undefined          undefined
# ...                                ...                ...
# 58571                        undefined          undefined
# 58653                        undefined          undefined
# 58711  Предоставление услуг эвакуатора          undefined
# 58715     Нагрудные  видеорегистраторы          undefined
# 58865                        undefined          undefined
#
# [241 rows x 61 columns]

# %%
# Корректируем ClientID
df['ym_clientid'] = df['ym_clientid'].apply(lambda x: get_id(x) if 'YA' in x else 'undefined', 1)
df
# Out:
#                ym_clientid ym_pervyj_istochnik_trafika      ym_source  \
# 0        15785624736522097                  Ad-Traffic      undefined
# 1       158240803283368197             Browser-Traffic      undefined
# 2      1594782414605357519                  Ad-Traffic      undefined
# 3      1595636421722944149                  Ad-Traffic      undefined
# 4      1600595766306691164                  Ad-Traffic  yad > 300x300
# ...                    ...                         ...            ...
# 60103            undefined                         NaN            NaN
# 60104            undefined                         NaN            NaN
# 60105            undefined                         NaN            NaN
# 60106            undefined                         NaN            NaN
# 60107            undefined                         NaN            NaN
#
#       ym_pervyj_perehod_s_sajtov ym_pervaja_poiskovaja_sistema ym_utm_source  \
# 0                      undefined                     undefined     undefined
# 1                      undefined                     undefined     undefined
# 2                      undefined                     undefined     undefined
# 3                      undefined                     undefined     undefined
# 4                      undefined                     undefined           yad
# ...                          ...                           ...           ...
# 60103                        NaN                           NaN           NaN
# 60104                        NaN                           NaN           NaN
# 60105                        NaN                           NaN           NaN
# 60106                        NaN                           NaN           NaN
# 60107                        NaN                           NaN           NaN
#
#       ym_utm_content    ym_gorod ym_data_vizita  ym_cost  ... crm_valjuta  \
# 0          undefined   undefined     2020-01-11     15.0  ...         NaN
# 1          undefined   undefined     2020-02-23      0.0  ...         NaN
# 2          undefined   undefined     2020-07-21     15.0  ...         NaN
# 3          undefined  Нур-Султан     2020-07-25     15.0  ...         NaN
# 4            300x300   undefined     2020-09-20     15.0  ...         NaN
# ...              ...         ...            ...      ...  ...         ...
# 60103            NaN         NaN            NaN      NaN  ...       Рубль
# 60104            NaN         NaN            NaN      NaN  ...       Рубль
# 60105            NaN         NaN            NaN      NaN  ...       Рубль
# 60106            NaN         NaN            NaN      NaN  ...       Рубль
# 60107            NaN         NaN            NaN      NaN  ...       Рубль
#
#        crm_povtornyj_lid  crm_utm_source  crm_utm_medium crm_utm_campaign  \
# 0                    NaN             NaN             NaN              NaN
# 1                    NaN             NaN             NaN              NaN
# 2                    NaN             NaN             NaN              NaN
# 3                    NaN             NaN             NaN              NaN
# 4                    NaN             NaN             NaN              NaN
# ...                  ...             ...             ...              ...
# 60103                  N       undefined       undefined        undefined
# 60104                  N       undefined       undefined        undefined
# 60105                  N       undefined       undefined        undefined
# 60106                  N       undefined       undefined        undefined
# 60107                  N       undefined       undefined        undefined
#
#        crm_utm_content  crm_utm_term  crm_klassifikator_otrasli  \
# 0                  NaN           NaN                        NaN
# 1                  NaN           NaN                        NaN
# 2                  NaN           NaN                        NaN
# 3                  NaN           NaN                        NaN
# 4                  NaN           NaN                        NaN
# ...                ...           ...                        ...
# 60103        undefined     undefined                  undefined
# 60104        undefined     undefined                  undefined
# 60105        undefined     undefined                  undefined
# 60106        undefined     undefined                  undefined
# 60107        undefined     undefined                  undefined
#
#                         crm_otrasl          crm_otrasl_spisok
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 60103   Производство печатных плат                  undefined
# 60104  Сервисное локомотивное депо  Сервис (депо, жд техника)
# 60105                    undefined                  undefined
# 60106                    undefined                  undefined
# 60107                    undefined                  undefined
#
# [60108 rows x 61 columns]

# %%
# Сохранение в файл
df.to_csv('../data/df_final.csv', index=False, encoding='utf-8', sep=';')
